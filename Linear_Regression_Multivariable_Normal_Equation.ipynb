# %% [markdown]
# <a href="https://colab.research.google.com/github/euguroglu/Machine-Learning-Projects/blob/master/Linear_Regression_Multivariable_Normal_Equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading Data

# %%
import math
import numpy as np
import sklearn
from matplotlib import pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-697ef3b2-a92e-4d73-a925-ed64742f80d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-697ef3b2-a92e-4d73-a925-ed64742f80d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ex1data2.txt to ex1data2.txt

# %%
data = np.loadtxt("ex1data2.txt",delimiter=",")
data

# %% [markdown]
# ## Visualization

# %%
x1 = data[:,0]
x2 = data[:,1]
x = data[:,0:2]
y  = data[:,2]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x1, x2, y, c = 'b', marker='o')
ax.set_xlabel('House size')
ax.set_ylabel('Number of bedroom')
ax.set_zlabel('House price')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() 
x_matrix = x.reshape((-1,2))
ones = np.ones((len(x),1))
A = np.append(x_matrix,ones,axis=1)
A

# %% [markdown]
# ## Normal Equation

# %%
At = A.T
pseudo_inv = np.linalg.inv(At.dot(A)).dot(At)
pseudo_inv

# %%
(theta0,theta1,theta2) = pseudo_inv.dot(y)
print('optimum weights are {},{},{}'.format(theta0,theta1,theta2))
theta_opt=np.array([[theta0],[theta1],[theta2]])
# Out:
# optimum weights are 139.2106740176261,-8738.019112328147,89597.90954279742

# %% [markdown]
# ## Predictions

# %%
z= A.dot(theta_opt)
z

# %%
epsilon = ((z-y)**2).mean()
math.sqrt(epsilon)
# Out:
# 162843.71258203

# %% [markdown]
# ## Regression Score

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(y, z)
# Out:
# 0.7329450180289143
