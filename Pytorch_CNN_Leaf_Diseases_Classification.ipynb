# %% [markdown]
# ## Importing Libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms, models
from torchvision.utils import make_grid

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sn
from sklearn.metrics import confusion_matrix

# %%
import os
from PIL import Image
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Data loading and preperation

# %%
train_transform = transforms.Compose([
   transforms.RandomRotation(0),
   transforms.RandomHorizontalFlip(),
   transforms.Resize(224),
   transforms.CenterCrop(224),
   transforms.ToTensor(),
   transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225]) 
])

# %%
test_transform = transforms.Compose([
   transforms.Resize(224),
   transforms.CenterCrop(224),
   transforms.ToTensor(),
   transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
])

# %%
root = 'RiceDiseaseDataset/'

train_data = datasets.ImageFolder(os.path.join(root,'train'),transform=train_transform)
test_data = datasets.ImageFolder(os.path.join(root,'test'),transform=test_transform)

train_loader = DataLoader(train_data,batch_size=10,shuffle=True)
test_loader = DataLoader(test_data,batch_size=10,shuffle=False)

class_names = train_data.classes

# %%
class_names
# Out:
# ['BrownSpot', 'Healthy', 'Hispa', 'LeafBlast']

# %%
len(train_data)
# Out:
# 1600

# %%
len(test_data)
# Out:
# 492

# %% [markdown]
# ## Data visualization

# %%
for i,(images,labels) in enumerate(train_loader):
    break

# %%
images.shape
# Out:
# torch.Size([10, 3, 224, 224])

# %%
im = make_grid(images, nrow=5)  # the default nrow is 8

# Inverse normalize the images
inv_normalize = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)
im_inv = inv_normalize(im)

plt.figure(figsize=(12,4))
plt.imshow(np.transpose(im_inv.numpy(), (1, 2, 0)))

# %% [markdown]
# ## Convolutional Neural Network

# %%
class ConvolutionalNetwork(nn.Module):
    
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Conv2d(3,6,3,1)
        self.conv2 = nn.Conv2d(6,16,3,1)
        self.fc1 = nn.Linear(54*54*16,120)
        self.fc2 = nn.Linear(120,84)
        self.fc3 = nn.Linear(84,7)
        
    def forward(self,X):
        
        X = F.relu(self.conv1(X))
        X = F.max_pool2d(X,2,2)
        X = F.relu(self.conv2(X))
        X = F.max_pool2d(X,2,2)
        X = X.view(-1,54*54*16)
        X = F.relu(self.fc1(X))
        X = F.dropout(X,p=0.2)
        X = F.relu(self.fc2(X))
        X = F.dropout(X,p=0.2)
        X = self.fc3(X)
        
        return F.log_softmax(X,dim=1)

# %%
model = ConvolutionalNetwork()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)

# %%
model
# Out:
# ConvolutionalNetwork(
#   (conv1): Conv2d(3, 6, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=46656, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=7, bias=True)
# )

# %% [markdown]
# ## Parameter check

# %%
for param in model.parameters():
    print(param.numel())
# Out:
# 162
# 6
# 864
# 16
# 5598720
# 120
# 10080
# 84
# 588
# 7

# %%
import time
start_time = time.time()

epochs = 20


train_losses = []
test_losses = []
train_correct = []
test_correct = []
accuracy = []
accuracy_test = []

for i in range(epochs):
    
    trn_corr = 0
    tst_corr = 0
    
    for b,(X_train,y_train) in enumerate(train_loader):
        
       
        b = b + 1
        
        y_pred = model(X_train)
        loss = criterion(y_pred,y_train)
        
        predicted = torch.max(y_pred.data,1)[1]
        batch_corr = (predicted == y_train).sum()
        trn_corr = trn_corr + batch_corr
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if b%100 == 0:
            print('Epoch:  {} Loss:  {} Accuracy:  {}'.format(i,loss,trn_corr.item()*100/(10*b)))
    accuracy.append((trn_corr.item()*100/(b*10)))
    train_losses.append(loss)
    train_correct.append(trn_corr)
    
    
    #test set
    
    with torch.no_grad():
        for b,(X_test,y_test) in enumerate(test_loader):
            b = b + 1
            y_val = model(X_test)
            predicted = torch.max(y_val.data,1)[1]
            batch_corr = (predicted == y_test).sum()
            tst_corr = tst_corr + batch_corr
            accuracy_test.append(tst_corr.item()*100/(10*b))
            if b%10 == 0:
                print('Accuracy:  {}'.format(tst_corr.item()*100/(10*b)))
    
    loss = criterion(y_val,y_test)
    test_losses.append(loss)
    test_correct.append(tst_corr)
            
    
total_time = time.time() - start_time
print(f'Total Time: {total_time/60}) minutes')
# Out:
# Epoch:  0 Loss:  1.1292849779129028 Accuracy:  31.5
# Accuracy:  53.0
# Accuracy:  35.5
# Accuracy:  33.0
# Accuracy:  39.25
# Accuracy:  37.2
# Epoch:  1 Loss:  1.446250319480896 Accuracy:  41.7
# Accuracy:  71.0
# Accuracy:  49.0
# Accuracy:  41.333333333333336
# Accuracy:  38.5
# Accuracy:  37.0
# Epoch:  2 Loss:  1.3820613622665405 Accuracy:  41.9
# Accuracy:  64.0
# Accuracy:  48.5
# Accuracy:  46.0
# Accuracy:  46.75
# Accuracy:  39.0
# Epoch:  3 Loss:  0.7257343530654907 Accuracy:  46.2
# Accuracy:  39.0
# Accuracy:  28.0
# Accuracy:  33.0
# Accuracy:  36.75
# Accuracy:  34.8
# Epoch:  4 Loss:  1.0180096626281738 Accuracy:  51.3
# Accuracy:  57.0
# Accuracy:  42.0
# Accuracy:  40.333333333333336
# Accuracy:  38.5
# Accuracy:  33.4
# Epoch:  5 Loss:  1.4930641651153564 Accuracy:  57.8
# Accuracy:  51.0
# Accuracy:  43.5
# Accuracy:  42.333333333333336
# Accuracy:  38.5
# Accuracy:  37.2
# Epoch:  6 Loss:  0.8061200976371765 Accuracy:  64.7
# Accuracy:  61.0
# Accuracy:  49.0
# Accuracy:  45.666666666666664
# Accuracy:  40.75
# Accuracy:  37.8
# Epoch:  7 Loss:  0.8663301467895508 Accuracy:  69.7
# Accuracy:  58.0
# Accuracy:  50.5
# Accuracy:  43.333333333333336
# Accuracy:  39.75
# Accuracy:  36.2
# Epoch:  8 Loss:  0.48628664016723633 Accuracy:  73.0
# Accuracy:  53.0
# Accuracy:  44.5
# Accuracy:  40.666666666666664
# Accuracy:  40.25
# Accuracy:  37.2
# Epoch:  9 Loss:  1.0201942920684814 Accuracy:  80.5
# Accuracy:  67.0
# Accuracy:  52.5
# Accuracy:  48.0
# Accuracy:  42.5
# Accuracy:  38.4
# Epoch:  10 Loss:  0.12790007889270782 Accuracy:  83.8
# Accuracy:  54.0
# Accuracy:  42.5
# Accuracy:  41.333333333333336
# Accuracy:  39.25
# Accuracy:  37.8
# Epoch:  11 Loss:  0.38325610756874084 Accuracy:  86.3
# Accuracy:  55.0
# Accuracy:  42.5
# Accuracy:  42.666666666666664
# Accuracy:  42.25
# Accuracy:  39.0
# Epoch:  12 Loss:  0.09540115296840668 Accuracy:  87.5
# Accuracy:  53.0
# Accuracy:  45.5
# Accuracy:  44.0
# Accuracy:  40.25
# Accuracy:  36.0
# Epoch:  13 Loss:  1.1014914512634277 Accuracy:  90.7
# Accuracy:  53.0
# Accuracy:  43.0
# Accuracy:  41.0
# Accuracy:  39.25
# Accuracy:  37.0
# Epoch:  14 Loss:  0.1706012785434723 Accuracy:  92.4
# Accuracy:  58.0
# Accuracy:  47.0
# Accuracy:  43.0
# Accuracy:  40.25
# Accuracy:  37.4
# Epoch:  15 Loss:  0.35345861315727234 Accuracy:  93.6
# Accuracy:  52.0
# Accuracy:  44.5
# Accuracy:  43.0
# Accuracy:  39.75
# Accuracy:  34.2
# Epoch:  16 Loss:  0.07241244614124298 Accuracy:  94.4
# Accuracy:  51.0
# Accuracy:  41.5
# Accuracy:  38.666666666666664
# Accuracy:  39.75
# Accuracy:  37.4
# Epoch:  17 Loss:  0.03661264106631279 Accuracy:  95.4
# Accuracy:  54.0
# Accuracy:  46.5
# Accuracy:  44.0
# Accuracy:  40.5
# Accuracy:  35.4
# Epoch:  18 Loss:  0.0033681890927255154 Accuracy:  95.5
# Accuracy:  55.0
# Accuracy:  47.0
# Accuracy:  41.666666666666664
# Accuracy:  37.75
# Accuracy:  34.2
# Epoch:  19 Loss:  0.029003852978348732 Accuracy:  97.3
# Accuracy:  40.0
# Accuracy:  39.5
# Accuracy:  38.333333333333336
# Accuracy:  36.5
# Accuracy:  33.6
# Total Time: 132.62993808984757) minutes

# %%
100*trn_corr.item()/len(train_data)
# Out:
# 97.0

# %%
100*tst_corr/len(test_data)
# Out:
# tensor(34)

# %%
plt.plot(train_losses,label='Train loss')
plt.plot(test_losses,label='Validation loss')
plt.title('Loss at epoch')
plt.legend()
plt.show()

# %%
plt.plot(range(20),accuracy)
plt.title('Train accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
plt.plot(range(1000),accuracy_test)

# %%
model.eval()

with torch.no_grad():
    tst_corr_2 = 0
    for b,(X_test,y_test) in enumerate(test_loader):
           
                        
        y_val = model(X_test)
        predicted = torch.max(y_val.data,1)[1]
        batch_corr = (predicted == y_test).sum()
        tst_corr = batch_corr + tst_corr

# %%
len(test_data)
# Out:
# 492

# %%
tst_corr
# Out:
# tensor(341)

# %%
# Create a loader for the entire the test set
test_load_all = DataLoader(test_data, batch_size=492, shuffle=False)

with torch.no_grad():
    correct = 0
    for X_test, y_test in test_load_all:
        y_val = model(X_test)
        predicted = torch.max(y_val,1)[1]
        correct += (predicted == y_test).sum()

arr = confusion_matrix(y_test.view(-1), predicted.view(-1))
df_cm = pd.DataFrame(arr, class_names, class_names)
plt.figure(figsize = (9,6))
sn.heatmap(df_cm, annot=True, fmt="d", cmap='BuGn')
plt.xlabel("prediction")
plt.ylabel("label (ground truth)")
plt.show();
