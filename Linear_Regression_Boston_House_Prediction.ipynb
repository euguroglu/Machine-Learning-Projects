# %% [markdown]
# <a href="https://colab.research.google.com/github/euguroglu/Machine-Learning-Projects/blob/master/Linear_Regression_Boston_House_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn
import sys
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('housing.data',delim_whitespace=True,header=None)

# %%
df
# Out:
#           0     1      2   3      4   ...     9     10      11    12    13
# 0    0.00632  18.0   2.31   0  0.538  ...  296.0  15.3  396.90  4.98  24.0
# 1    0.02731   0.0   7.07   0  0.469  ...  242.0  17.8  396.90  9.14  21.6
# 2    0.02729   0.0   7.07   0  0.469  ...  242.0  17.8  392.83  4.03  34.7
# 3    0.03237   0.0   2.18   0  0.458  ...  222.0  18.7  394.63  2.94  33.4
# 4    0.06905   0.0   2.18   0  0.458  ...  222.0  18.7  396.90  5.33  36.2
# ..       ...   ...    ...  ..    ...  ...    ...   ...     ...   ...   ...
# 501  0.06263   0.0  11.93   0  0.573  ...  273.0  21.0  391.99  9.67  22.4
# 502  0.04527   0.0  11.93   0  0.573  ...  273.0  21.0  396.90  9.08  20.6
# 503  0.06076   0.0  11.93   0  0.573  ...  273.0  21.0  396.90  5.64  23.9
# 504  0.10959   0.0  11.93   0  0.573  ...  273.0  21.0  393.45  6.48  22.0
# 505  0.04741   0.0  11.93   0  0.573  ...  273.0  21.0  396.90  7.88  11.9
#
# [506 rows x 14 columns]

# %%
col_name = ['CRIM', 'ZN' , 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
df.columns = col_name

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222.0     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Data Analysis

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %%
sns.pairplot(df,height=2.5)
plt.show()

# %%
col_study = ['CRIM','ZN','INDUS','NOX','RM']

# %%
sns.pairplot(df[col_study],height=2.5)
plt.show()

# %%
col_study = ['PTRATIO','B','LSTAT','MEDV']

# %%
sns.pairplot(df[col_study],height=2.5)
plt.show()

# %% [markdown]
# ## Correlation Analysis and Feature Selection

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
df.corr()
# Out:
#           CRIM     ZN  INDUS   CHAS    NOX  ...    TAX  PTRATIO      B  LSTAT   MEDV
# CRIM     1.000 -0.200  0.407 -0.056  0.421  ...  0.583    0.290 -0.385  0.456 -0.388
# ZN      -0.200  1.000 -0.534 -0.043 -0.517  ... -0.315   -0.392  0.176 -0.413  0.360
# INDUS    0.407 -0.534  1.000  0.063  0.764  ...  0.721    0.383 -0.357  0.604 -0.484
# CHAS    -0.056 -0.043  0.063  1.000  0.091  ... -0.036   -0.122  0.049 -0.054  0.175
# NOX      0.421 -0.517  0.764  0.091  1.000  ...  0.668    0.189 -0.380  0.591 -0.427
# RM      -0.219  0.312 -0.392  0.091 -0.302  ... -0.292   -0.356  0.128 -0.614  0.695
# AGE      0.353 -0.570  0.645  0.087  0.731  ...  0.506    0.262 -0.274  0.602 -0.377
# DIS     -0.380  0.664 -0.708 -0.099 -0.769  ... -0.534   -0.232  0.292 -0.497  0.250
# RAD      0.626 -0.312  0.595 -0.007  0.611  ...  0.910    0.465 -0.444  0.489 -0.382
# TAX      0.583 -0.315  0.721 -0.036  0.668  ...  1.000    0.461 -0.442  0.544 -0.469
# ...

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
sns.heatmap?

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df[['CRIM','ZN','INDUS','CHAS','MEDV']].corr(),annot=True)
plt.show()

# %% [markdown]
# ## Linear Regression with Sklearn (One feature)

# %%
X = df['RM'].values.reshape(-1,1)

# %%
y = df['MEDV'].values

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Creating Model

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Observing beta coeeficient and quasi value

# %%
model.coef_
# Out:
# array([9.10210898])

# %%
model.intercept_
# Out:
# -34.67062077643857

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(12,10))
sns.regplot(X,y)
plt.xlabel('Average number of rooms per dwelling')
plt.ylabel("Median value of owner-occupied homes in 1000$'s")
plt.show()

# %%
sns.jointplot(x='RM',y='MEDV',data=df,kind='reg',height=10)
plt.show()

# %% [markdown]
# ## Prediction

# %%
model.predict(np.array([5]).reshape(-1,1))
# Out:
# array([10.83992413])

# %% [markdown]
# ## Linear Regression using another feautre

# %%
model2 = LinearRegression()
X = df['LSTAT'].values.reshape(-1,1)
y = df['MEDV'].values
model2.fit(X,y)
plt.figure(figsize=(12,10))
sns.regplot(X,y)
plt.xlabel('Low status of the population %')
plt.ylabel("Median value of owner-occupied homes in 1000$'s")
plt.show()

# %%
model2.predict(np.array([15]).reshape(-1,1))
# Out:
# array([20.30310057])
